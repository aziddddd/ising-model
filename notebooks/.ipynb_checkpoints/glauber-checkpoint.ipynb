# %% [markdown]
# #### Import required packages

# %%
# %matplotlib notebook

import im_utils
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# #### Initialisation

# %%
N           = 50                             # System size
temp        = .4
method      = 'glauber'                      # glauber or kawasaki

# %% [markdown]
# #### Methods

# %%
ising_model = im_utils.Ising(N, temp, method)

# %% [markdown]
# #### Results

# %% [markdown]
# - Snapshots

# %%
ising_model.snapshots(500)
# Out:
#   0%|          | 1/500 [00:01<12:56,  1.56s/it]
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 500/500 [00:49<00:00,  8.50it/s]

# %% [markdown]
# - Dynamic plotting

# %%
# %matplotlib inline

ising_model.DynamicPlot(500)

# %% [markdown]
# - Animation (Faster)

# %%
# %%time

plotFigure = plt.figure(figsize=(5, 5), dpi=80)
animate = animation.FuncAnimation(plotFigure, ising_model.simulate, interval=1, repeat=False)
