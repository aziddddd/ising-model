# %% [markdown]
# #### Import required packages

# %%
# %matplotlib notebook

import im_utils
import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# #### Initialisation

# %%
N           = 50                             # System size
temp        = .4
method      = 'glauber'                      # glauber or kawasaki

# %% [markdown]
# #### Methods

# %%
ising_model = im_utils.Ising(N, temp, method)

# %% [markdown]
# #### Results

# %% [markdown]
# - Snapshots

# %%
ising_model.snapshots(500)
# Out:
#   0%|▏                                                                                 | 1/500 [00:00<07:02,  1.18it/s]
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:16<00:00, 27.89it/s]

# %% [markdown]
# - Dynamic plotting

# %%
# %matplotlib inline

ising_model.DynamicPlot(500)

# %% [markdown]
# - Animation

# %%
# %%time

plotFigure = plt.figure(figsize=(5, 5), dpi=80)
animate = animation.FuncAnimation(plotFigure, ising_model.simulate, interval=1, repeat=False)
