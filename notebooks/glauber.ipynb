# %% [markdown]
# #### Import required packages

# %%
# %matplotlib notebook

import im_utils
import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# #### Initialisation

# %%
N           = 50                             # System size
temp        = .4
method      = 'glauber'                      # glauber or kawasaki
temp_point  = 88
temp_range  = (1.53, 3.28)
equistep    = 100
calcstep    = 10

# %% [markdown]
# #### Methods

# %%
ising_model = im_utils.Ising(N, temp, method, temp_point, temp_range, equistep, calcstep)

# %% [markdown]
# #### Results

# %% [markdown]
# - Snapshots

# %%
ising_model.snapshots(500)
# Out:
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# - Dynamic plotting (Smoother)

# %%
# %matplotlib inline

ising_model.DynamicPlot(500)

# %% [markdown]
# - Animation

# %%
# %%time

plotFigure = plt.figure(figsize=(5, 5), dpi=80)
animate = animation.FuncAnimation(plotFigure, ising_model.simulate, interval=1, repeat=False)

# %% [markdown]
# - Method behavior
#     - Energy
#     - Magnetisation
#     - Susceptibility
#     - Heat Capacity

# %%
from __future__ import division
ising_model.analyse()
# Out:
# HBox(children=(IntProgress(value=0, max=88), HTML(value='')))
# <img src="data:image/png;base64,..." width="640">
